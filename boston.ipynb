# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
boston=pd.read_csv("HousingData.csv")

# %%
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
boston.keys()
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %% [markdown]
# #### Preparing The Dataset

# %% [markdown]
# #### Summarizing the states of data

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# #### chech the missing values

# %%
boston.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
boston.fillna(boston.median(), inplace=True)

# %%
boston.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
boston.hist(figsize=(12, 10), bins=30, edgecolor='black')
plt.suptitle('Histograms of Numerical Features')
plt.show()

# %% [markdown]
# #### EDA , Corrlation

# %%
boston.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.185359  0.392632 -0.055585  0.410971 -0.220045  0.343427
# ZN      -0.185359  1.000000 -0.507304 -0.032992 -0.498619  0.312295 -0.535341
# INDUS    0.392632 -0.507304  1.000000  0.054693  0.738387 -0.377978  0.614248
# CHAS    -0.055585 -0.032992  0.054693  1.000000  0.070867  0.106797  0.074984
# NOX      0.410971 -0.498619  0.738387  0.070867  1.000000 -0.302188  0.711864
# RM      -0.220045  0.312295 -0.377978  0.106797 -0.302188  1.000000 -0.239518
# AGE      0.343427 -0.535341  0.614248  0.074984  0.711864 -0.239518  1.000000
# DIS     -0.366025  0.632428 -0.698621 -0.092318 -0.769230  0.205246 -0.724354
# RAD      0.601224 -0.300061  0.592735 -0.003339  0.611441 -0.209847  0.447088
# TAX      0.560469 -0.304385  0.716267 -0.035822  0.668023 -0.292048  0.498408
# PTRATIO  0.277964 -0.394622  0.385366 -0.109451  0.188933 -0.355501  0.261826
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(boston, hue='MEDV', palette='viridis')

# %%
plt.scatter(boston['CRIM'], boston['MEDV'])
plt.xlabel("Crime Rate")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(boston['RM'], boston['MEDV'])
plt.xlabel("RM")
plt.ylabel("Price 100k ")
# Out:
# Text(0, 0.5, 'Price 100k ')

# %%
sns.regplot(x = "RM" , y="MEDV" , data = boston)
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %%
sns.regplot(x = "LSTAT" , y="MEDV" , data = boston)
# Out:
# <Axes: xlabel='LSTAT', ylabel='MEDV'>

# %%
sns.regplot(x = "CHAS" , y="MEDV" , data = boston)
# Out:
# <Axes: xlabel='CHAS', ylabel='MEDV'>

# %%
sns.regplot(x = "PTRATIO" , y="MEDV" , data = boston)
# Out:
# <Axes: xlabel='PTRATIO', ylabel='MEDV'>

# %%
### Depended amd Imdepended features

X=boston.iloc[: , :-1]
y = boston.iloc[: , -1]

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90  11.43

# %%
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: MEDV, dtype: float64

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
## Train Test Split

from sklearn.model_selection import train_test_split 

X_train , X_test , y_train ,y_test = train_test_split(X,y,test_size = .3 , random_state=42)

# %%
X_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 5     0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# 116   0.13158   0.0  10.01   0.0  0.547  6.176  72.5  2.7301    6  432
# 45    0.17142   0.0   6.91   0.0  0.448  5.682  33.8  5.1004    3  233
# 16    1.05393   0.0   8.14   0.0  0.538  5.935  29.3  4.4986    4  307
# 468  15.57570   0.0  18.10   0.0  0.580  5.926  71.0  2.9084   24  666
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 106   0.17120   0.0   8.56   0.0  0.520  5.836  91.9  2.2110    5  384
# 270   0.29916  20.0   6.96   0.0  0.464  5.856  42.1  4.4290    3  223
# 348   0.01501  80.0   2.01   0.0  0.435  6.635  29.7  8.3440    4  280
# 435  11.16040   0.0  18.10   0.0  0.740  6.629  94.6  2.1247   24  666
# 102   0.22876   0.0   8.56   0.0  0.520  6.405  85.4  2.7147    5  384
#
#      PTRATIO       B  LSTAT
# 5       18.7  394.12   5.21
# 116     17.8  393.30  11.43
# ...

# %%
## standardize 

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %% [markdown]
# ### Model Training

# %%
from sklearn.linear_model import LinearRegression

regression = LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(regression.coef_)
# Out:
# [-1.03139352  0.68235072 -0.05344167  0.95797829 -1.61846531  3.14830411
#  -0.65443065 -2.98754714  1.64431524 -1.17863385 -2.00667634  1.00071526
#  -3.34283682]

# %%
print(regression.intercept_)
# Out:
# 23.01581920903955

# %%
## reg Information
regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
reg_pred = regression.predict(X_test)

# %%
reg_pred
# Out:
# array([30.88378272, 39.19999852, 16.80491869, 26.8705368 , 20.02662636,
#        24.70607103, 19.40387821, 15.83569961, 23.5284843 , 22.35149144,
#        27.54725739, 20.64187366, -4.19807316, 23.51401051, 20.28155682,
#        27.73386213, 20.97339017,  6.89290786, 43.4688126 , 18.7222365 ,
#        26.92961783, 32.01539091, 12.58902512, 24.78042382, 19.05997737,
#        16.43169306, 23.4402134 , 16.9221204 , 24.79990731, 20.96457831,
#        24.01937771, 26.71191879, 27.2038473 , 18.42708384, 17.77282065,
#        19.81468865, 33.04198188, 21.44121218, 26.63846092, 24.85165853,
#        15.79163266, 33.54762981, 45.39249638, 19.17598031, 29.24738052,
#        17.87592883, 15.13770672, 27.96145749, 21.16825355, 32.56781848,
#        23.17121703, 35.77566867, 17.26232986, 27.7615222 , 42.61479765,
#        23.83852255, 19.96680861, 34.33743439, 26.89272033, 14.11550819,
#        24.2125296 , 32.57842801, 33.79111981, 17.74361856, 22.68451301,
# ...

# %%
## plot scatter plot for predictions

plt.scatter(y_test , reg_pred)

# %%
residuals = y_test - reg_pred

# %%
residuals
# Out:
# 173   -7.283783
# 274   -6.799999
# 491   -3.204919
# 72    -4.070537
# 452   -3.926626
#          ...
# 441   -5.615835
# 23    -0.273162
# 225    6.852854
# 433   -4.159448
# 447   -6.839081
# Name: MEDV, Length: 152, dtype: float64

# %%
sns.displot(residuals,kind='kde')

# %%
plt.scatter(reg_pred,residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
# Out:
# 3.7370647767374416
# 24.498050225566953

# %%
## r squre and adjusted square

# %%
from sklearn.metrics import r2_score 
score = r2_score(y_test , reg_pred)
print(score)
# Out:
# 0.6712249029668353

# %%
1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.6402533358550155

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 regression(X_test[0])
#
# TypeError: 'LinearRegression' object is not callable

# %% [markdown]
# ## Pickling the model

# %%
import pickle

# %%
pickle.dump(regression , open("regmodl.pkl" , "wb"))
